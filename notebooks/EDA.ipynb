# %%
import pandas as pd
df = pd.read_csv('Resume/Resume.csv')

# %%
df.head(100)
# Out:
#           ID                                         Resume_str  \
# 0   16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1   22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2   33176873           HR DIRECTOR       Summary      Over 2...
# 3   27018550           HR SPECIALIST       Summary    Dedica...
# 4   17812897           HR MANAGER         Skill Highlights  ...
# ..       ...                                                ...
# 95  28640735           DIRECTOR OF HR           Executive Pr...
# 96  15575117           HR SENIOR SPECIALIST       Career Ove...
# 97  27496514           HR CUSTOMER SERVICE REPRESENTATIVE   ...
# 98  14256329           HR SERVICES REPRESENTATIVE       Summ...
# 99  19336728           HR ASSISTANT INTERN       Summary    ...
#
#                                           Resume_html Category
# 0   <div class="fontsize fontface vmargins hmargin...       HR
# 1   <div class="fontsize fontface vmargins hmargin...       HR
# ...

# %%
# Filter the DataFrame
df = df[df['Category'].isin(['HR', 'INFORMATION-TECHNOLOGY'])]

# Verify the results
print(df['Category'].unique())
# Out:
# ['HR' 'INFORMATION-TECHNOLOGY']

# %%
df
# Out:
#            ID                                         Resume_str  \
# 0    16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1    22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2    33176873           HR DIRECTOR       Summary      Over 2...
# 3    27018550           HR SPECIALIST       Summary    Dedica...
# 4    17812897           HR MANAGER         Skill Highlights  ...
# ..        ...                                                ...
# 332  27485716           CORPORATE PROJECT MANAGER       Caree...
# 333  26480367           IT TECHNOLOGY SPECIALIST       Profes...
# 334  81761658           IT MANAGER             Highlights    ...
# 335  79541391           SUBJECT MATTER EXPERT (INFORMATION TE...
# 336  23666211           TRAINING MANAGER         Executive Su...
#
#                                            Resume_html                Category
# 0    <div class="fontsize fontface vmargins hmargin...                      HR
# ...

# %%
df.to_csv('Resume/Resume.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230 entries, 0 to 336
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           230 non-null    int64
#  1   Resume_str   230 non-null    object
#  2   Resume_html  230 non-null    object
#  3   Category     230 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 9.0+ KB
